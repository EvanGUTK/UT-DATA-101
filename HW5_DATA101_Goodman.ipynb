# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("mortality.csv")

# Display the first 10 records
print("\nFirst 10 records:")
print(df.head(10))

print("\nNumber of rows and columns:", df.shape)

# Display the records indexed 50 through 61
print("\nRecords from index 50 to 61:")
print(df.iloc[50:62])

print("\nColumn names:")
print(df.columns)

print("\nSummary of Stats:") 
print(df.describe())

print("\nSeries:")
death_rate_series = df["Death Rate"] 
print(death_rate_series.head())

print("\nRows 0 through 10 for columns 1 and 2:")
print(df.iloc[0:11, 1:3])

# display the average, minimum, and maximum death rate
average_death_rate = df["Death Rate"].mean()
min_death_rate = df["Death Rate"].min()
max_death_rate = df["Death Rate"].max()

print("\nDeath Rate Stats:")
print(f"Average Death Rate: {average_death_rate}")
print(f"Minimum Death Rate: {min_death_rate}")
print(f"Maximum Death Rate: {max_death_rate}")

# Plot
plt.plot(total_deaths_by_year)
plt.xlabel("Year") 
plt.ylabel("Total Death Rate") 
plt.title("Total Death Rate by Year") 
plt.show()
# Out:
# First 10 records:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0
# 2  1902  1-4 Years      1655.7
# 3  1903  1-4 Years      1542.1
# 4  1904  1-4 Years      1591.5
# 5  1905  1-4 Years      1498.9
# 6  1906  1-4 Years      1580.0
# 7  1907  1-4 Years      1468.3
# 8  1908  1-4 Years      1396.8
# 9  1909  1-4 Years      1348.9
#
# Number of rows and columns: (476, 3)
#
# Records from index 50 to 61:
#     Year  Age Group  Death Rate
# 50  1950  1-4 Years       139.4
# 51  1951  1-4 Years       136.9
# 52  1952  1-4 Years       141.1
# 53  1953  1-4 Years       130.0
# 54  1954  1-4 Years       118.3
# 55  1955  1-4 Years       113.4
# 56  1956  1-4 Years       110.2
# 57  1957  1-4 Years       111.8
# 58  1958  1-4 Years       111.7
# 59  1959  1-4 Years       106.9
# 60  1960  1-4 Years       109.1
# 61  1961  1-4 Years       101.7
#
# Column names:
# Index(['Year', 'Age Group', 'Death Rate'], dtype='object')
#
# Summary of Stats:
# ...
